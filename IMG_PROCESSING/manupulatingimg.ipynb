# %%
from PIL import Image

# %%
cheems=Image.open('ch.jpg')
bob = Image.open('dogex.jpg')



cheems
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x512 at 0x1C66F01F850>

# %%
w, h = cheems.size

# %%
resize_cheems = cheems.resize((w//4 ,h//4))
resize_cheems
# Out:
# <PIL.Image.Image image mode=RGB size=128x128 at 0x1C66FEAD910>

# %%
Image.blend(resize_cheems, bob.resize((w//4, h//4)), 0.4)
# Out:
# <PIL.Image.Image image mode=RGB size=128x128 at 0x1C66FDC03A0>

# %%
import os

# %%
for i in os.listdir():
    if i.endswith('jpg'):
        print(i)
# Out:
# ch.jpg
# dogex.jpg

# %%
bob.save('thumb.jpg')
